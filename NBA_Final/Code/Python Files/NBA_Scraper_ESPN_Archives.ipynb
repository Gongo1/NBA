# %%
#Libraries
from bs4 import BeautifulSoup as bsp
import requests
import pandas as pd
import names
import re
import urllib
import os
import time
import unicodedata
start = time.time()
os.chdir("/Users/Austin/Desktop/NBA/")

# %%
#Add full url as a feature... base_url + link 

#2018 Season 
#October when season begins 
base_url = 'http://www.espn.com/nba/news/archive/_/month/february/year/2017'
output_directory = "data/"
#----------------------------------------------------

# %%
#----------------------------------------------------
''' Collect all article links from HTML using base_url '''

# connect to server, randomize user-agent tag to enable prolonged iterations
req = requests.get(base_url, headers=({'User-Agent' : names.get_full_name()}))
# get the html content from the webpage
r = req.content
# 'soup' it
soup = bsp(r, 'lxml')

#We only want 2019 rn 
nba_articles = []
for tag in soup.findAll('a', href=True):
    nba_articles.append(tag['href'])
    #print (tag['href'])
    
    

#nba_articles[1:1000]

#Getting new links for only articles written about NBA
#Scraping brought up a lot of articles related to espn but not NBA 

nba_url = [s for s in nba_articles if 'http://www.espn.com/nba/' in s]

# %%
start = time.time()

os.chdir("interim/")
df = pd.DataFrame(columns=['Body', 'Date', 'Title'])
name = ['']
for URL in nba_url:
    page = requests.get(URL)
    soup = bsp(page.content, 'html.parser')
    results = soup.find(id='article-feed')
    #print(results.prettify())
    if results.find_all('div', class_='container') == "NoneType":
            break
    job_elems = results.find_all('div', class_='container')
    
    for job_elem in job_elems:
        # Each job_elem is a new BeautifulSoup object.
        # You can use the same methods on it as you did before.
        title_elem = job_elem.find('header', class_='article-header')
        body_elem = job_elem.find('div', class_='article-body')
        date_elem = job_elem.find('span', class_='timestamp')
        #make into pandas dataframe to import R 
        if None in (title_elem, body_elem, date_elem):
            continue
        # {Title, Date, Body, Link}
        print("Retrieving information for: ", title_elem.text.strip())
        d = {"Title": [title_elem.text.strip()], 'Body': [body_elem.text.strip()], "Date": [date_elem.text.strip()]}
        #making df for R 
        new_df = pd.DataFrame(data = d)
        name = date_elem
    name = date_elem
    #print(name)
    df = df.append(new_df)
# Out:
# Retrieving information for:  How two uneasy moments made Cavs better equipped for Warriors
# Retrieving information for:  NBA's report reveals 3 errors in final minutes of Knicks-Raptors
# Retrieving information for:  Andrew Bogut to join Cavaliers once he clears waivers
# Retrieving information for:  Report: Former Heat guard Norris Cole to join Thunder
# Retrieving information for:  Bucks' Michael Beasley out next 3 games with knee injury
# Retrieving information for:  Wiaards' Markieff Morris fined $25K for throwing ball
# Retrieving information for:  Pelicans' DeMarcus Cousins suspended one game after 18th technical foul
# Retrieving information for:  Chris Bosh: 'My health is great. I'm feeling good, still working out'
# Retrieving information for:  Deron Williams on his Cavs signing: 'This was the best fit for me'
# Retrieving information for:  Pistons honor Richard Hamilton retiring his No. 32 jersey
# Retrieving information for:  Global talent gets NBA treatment at Basketball Without Borders camp
# Retrieving information for:  Power Rankings: No. 1 Warriors set for cross-country trek
# Retrieving information for:  76ers waive Andrew Bogut, Lakers waive Jose Calderon to complete buyouts
# Retrieving information for:  League: Dwight Howard shouldn't have been ejected from Hawks' win
# Retrieving information for:  Avery Bradley returns for Celtics after being sidelined with Achilles strain
# Retrieving information for:  Bucks' Michael Beasley sprains knee, scheduled for further tests
# Retrieving information for:  Raptors hope to have Kyle Lowry back in time for playoffs
# Retrieving information for:  Clippers reportedly exploring potential move to Inglewood
# Retrieving information for:  Brandon Jennings waived by Knicks, who sign Chasson Randle
# Retrieving information for:  Joakim Noah likely done for season with knee injury
# Retrieving information for:  LeBron James returns after missing 1 game with strep throat
# Retrieving information for:  Raptors hope to have Kyle Lowry back in time for playoffs
# Retrieving information for:  DeMarcus Cousins picks up 18th technical, faces one-game suspension
# Retrieving information for:  Joel Embiid, battling knee swelling and soreness, sent for MRI
# Retrieving information for:  Nets waive veteran F Luis Scola to focus on their younger players
# Retrieving information for:  Sources: Andrew Bogut negotiating 76ers release, wants to join Cavs
# Retrieving information for:  Mark Cuban says draft factored into Mavericks' roster moves
# Retrieving information for:  Hawks say team have requested waivers on Lamar Patterson
# Retrieving information for:  Mavs sign Ben Bentil, Quinn Cook to fill spots following roster shuffle
# Retrieving information for:  Rudy Gobert fined $25K for contact with official
# Retrieving information for:  Philadelphia 76ers players laud Ben Simmons' work ethic, positivity
# Retrieving information for:  Jose Calderon securing buyout from Lakers to join Warriors
# Retrieving information for:  Derrick Rose's agent says player wants to remain in New York
# Retrieving information for:  Sources: Deron Williams clears waivers, informs Cavs he'll sign
# Retrieving information for:  Wildcats draw first blood in NBL grand final series
# Retrieving information for:  LeBron James misses Saturday's game against Bulls due to strep
# Retrieving information for:  Anthony Morrow won't wear ex-Bull Derrick Rose's No. 1 after backlash
# Retrieving information for:  Reggie Williams signs 10-day deal; Omri Casspi waived after debut
# Retrieving information for:  Why we won't stop talking about Lin vs. Kobe and the Lakers
# Retrieving information for:  Jeremy Lin is still a symbol for whatever we want him to be
# Retrieving information for:  What it's like when people start calling you the 'next Jeremy Lin'
# Retrieving information for:  Warriors sought intervention in Shaq-JaVale McGee feud
# Retrieving information for:  Isaiah Thomas on DeMarre Carroll flagrant: 'Guys who aren't factors do that'
# Retrieving information for:  Chris Paul returns to action from thumb injury in Clippers' loss
# Retrieving information for:  Kyle Lowry's wrist injury 'huge blow' for Raptors, Dwane Casey says
# Retrieving information for:  Dwyane Wade: Will focus on play, leave decisions to Bulls
# Retrieving information for:  Dennis Schroder suspended one game; PG was delayed in Germany waiting for new visa
# Retrieving information for:  Cowbell Kingdom podcast: Kings win playing like a team, and fans loved it
# Retrieving information for:  Kevin Love says he'll be prepared for postseason after 'very minor' surgery
# Retrieving information for:  Suns waive Mike Scott, Jared Sullinger; sign Ronnie Price
# Retrieving information for:  Knicks' Kristaps Porzingis says 'no ligament damage' in ankle
# Retrieving information for:  Sixers' Jahlil Okafor didn't take trade talks as a negative
# Retrieving information for:  Spurs at full strength as Pau Gasol, Manu Ginobili returning to lineup
# Retrieving information for:  Bulls' Jimmy Butler: 'I just want to win at all costs'
# Retrieving information for:  Jarrett Jack signs 10-day deal to return to Pelicans
# Retrieving information for:  Hawks sign Ryan Kelly, Lamar Patterson to multiyear deals
# Retrieving information for:  Paul Pierce to Draymond Green: '3-1 lead oops'
# Retrieving information for:  Sixers say Ben Simmons won't play this season; rookie star 'heartbroken' over news
# Retrieving information for:  DeMarcus Cousins: No point in talking to Kings brass about 'coward move'
# Retrieving information for:  Utah coach Snyder expects Hood to return from injury Friday
# Retrieving information for:  Paul George after failed trade talks: Wish I was in loop a little more
# Retrieving information for:  Pelicans lose as DeMarcus Cousins shines, Omri Casspi breaks thumb
# Retrieving information for:  Why the Celtics stood pat, for now
# Retrieving information for:  Carmelo Anthony unsure of team's direction after no deadline moves
# Retrieving information for:  Mavs waive Deron Williams, who wants to go to Cavs, sources say
# Retrieving information for:  Thunder get Taj Gibson, Doug McDermott, 2nd-rounder from Bulls
# Retrieving information for:  Charles Oakley sits courtside at Knicks-Cavaliers with Dan Gilbert
# Retrieving information for:  Omri Casspi says he'll miss 4 weeks with broken right thumb
# Retrieving information for:  Chris Bosh to continue working as Turner Sports television analyst
# Retrieving information for:  Mavericks trade Andrew Bogut, Justin Anderson to 76ers for Nerlens Noel
# Retrieving information for:  Rockets deal K.J. McDaniels to Nets, Tyler Ennis to Lakers
# Retrieving information for:  Clippers' Chris Paul (left thumb) remains out for Warriors game
# Retrieving information for:  NBA Trade Tracker: Every deadline deal
# Retrieving information for:  Pelicans waive Terrence Jones so he can pursue other options
# Retrieving information for:  Paul George: 'I'm committed' to turnaround of Pacers
# Retrieving information for:  Sources: Raptors trade center Jared Sullinger to Suns for P.J. Tucker
# Retrieving information for:  NBL Grand Final Series preview: Perth Wildcats vs Illawarra Hawks
# Retrieving information for:  Danny Ainge OK with Celtics standing pat at trade deadline
# Retrieving information for:  Vote: Who won and lost at the NBA trade deadline?
# Retrieving information for:  Sources: Suns get forward Mike Scott from Hawks for cash
# Retrieving information for:  Bucks trade Roy Hibbert to Nuggets for second-round pick
# Retrieving information for:  Joel Embiid upset with 76ers for lack of clarity over knee injury
# Retrieving information for:  NBA trade deadline: Latest news, rumblings and reports
# Retrieving information for:  Cavs to kick tires on shot-blocking expert Larry Sanders
# Retrieving information for:  Hawks get Ersan Ilyasova, trade Tiago Splitter to Sixers
# Retrieving information for:  Joel Embiid bids farewell to Nerlens Noel
# Retrieving information for:  Magic and Bird get reacquainted as Lakers look in on Pacers star Paul George, sources say
# Retrieving information for:  Sources: Pistons open to Andre Drummond, Kentavious Caldwell-Pope offers
# Retrieving information for:  What have we learned so far from the NBA uniform ads?
# Retrieving information for:  Clippers' Paul Pierce on board with China's Jr. NBA program
# Retrieving information for:  Warriors' Zaza Pachulia, David West exptected back vs. Clippers
# Retrieving information for:  Yao Ming voted president of Chinese Basketball Association
# Retrieving information for:  NBA Insiders: Will Dallas move Andrew Bogut ?
# Retrieving information for:  Jazz guard Rodney Hood (knee) targets Friday return
# Retrieving information for:  CK's interviews with newly acquired players
# Retrieving information for:  Tom Thibodeau on Wolves trade rumors: 'I like the guys we have'
# Retrieving information for:  Wizards get Bojan Bogdanovic in trade with Nets
# Retrieving information for:  Sacramento radio host kept off the air over remarks made criticizing Kings GM
# Retrieving information for:  Carmelo Anthony feeling relaxed heading into trade deadline
# Retrieving information for:  Thunder's Enes Kanter returns to practice after arm surgery
# Retrieving information for:  DeMarcus Cousins: 'Not sour ... not mad' about Kings-to-Pelicans trade
# Retrieving information for:  Miles Plumlee out at least 2 weeks with strained calf
# Retrieving information for:  Clippers' Chris Paul (thumb) may return as early as Thursday
# Retrieving information for:  Rockets want Iman Shumpert but not for Patrick Beverley
# Retrieving information for:  Suns again assign slam-dunk runner-up Derrick Jones Jr. to D-league
# Retrieving information for:  Cavs' Derrick Williams getting second 10-day contract
# Retrieving information for:  Sources: Lakers send Lou Williams to Rockets for Corey Brewer, pick
# Retrieving information for:  Magic Johnson says he had other offers but wants to fix the Lakers
# Retrieving information for:  Pacers reach out to 76ers to inquire about Jahlil Okafor
# Retrieving information for:  Sources: Jazz express interest in Deron Williams via trade from Mavericks
# Retrieving information for:  Pelicans' DeMarcus Cousins to switch jersey number from 15 to 0
# Retrieving information for:  Sources: Wolves, others inquire about Knicks' Derrick Rose
# Retrieving information for:  Big questions, lots of answers before NBA trade deadline
# Retrieving information for:  Boogie expresses his gratitude to Kings fans in an emotional Instagram post
# Retrieving information for:  Boogie is greeted with Southern hospitality
# Retrieving information for:  James Harden and the Rockets got super serious about winning
# Retrieving information for:  DeMarcus Cousins says farewell: Love for Sacramento 'is still here'
# Retrieving information for:  Kings GM Vlade Divac on DeMarcus Cousins trade: 'I had a better deal 2 days ago'
# Retrieving information for:  Power Rankings: Pelicans vault 10 spots after landing Cousins
# Retrieving information for:  Kings waive Matt Barnes to create post-trade roster space
# Retrieving information for:  Pelicans officially acquire DeMarcus Cousins in blockbuster trade with Kings
# Retrieving information for:  DeMarcus Cousins trade FAQ: Key questions on huge deal
# Retrieving information for:  Glenn Robinson III tops Derrick Jones Jr. to win slam dunk contest
# Retrieving information for:  Adam Silver: Age issue 'needs to be studied' outside CBA negotiations
# Retrieving information for:  Sources: Pistons discuss sending Reggie Jackson to Magic
# Retrieving information for:  'My dream is to make basketball the second-most popular sport in India'
# Retrieving information for:  Vivek Ranadive wants Kings to play preseason games in India
# Retrieving information for:  Sources: Kings strongly considering trading DeMarcus Cousins to Pelicans
# Retrieving information for:  Pelton mailbag: Where would Jahlil Okafor fit best?
# Retrieving information for:  Jimmer Fredette scores 73 points in Chinese league game
# Retrieving information for:  Brazil's Oscar Schmidt dips toes into NBA -- as celebrity
# Retrieving information for:  Anthony Davis breaks Wilt's All-Star scoring record, earns MVP honors
# Retrieving information for:  Perth through to NBL grand final series after defeating Cairns
# Retrieving information for:  One reunion alley-oop can't heal Westbrook-Durant split
# Retrieving information for:  Kevin Durant, Russell Westbrook connect on lob during All-Star Game
# Retrieving information for:  NBA All-Star 2017: News, schedule, rosters, results
# Retrieving information for:  David Robinson, Grant Hill honored at Legends Brunch
# Retrieving information for:  Frank Kaminsky channels 'Always Sunny' with All-Star Weekend look
# Retrieving information for:  Joel Embiid, Michael Jordan come together for picture at NBA All-Star Weekend
# Retrieving information for:  Cavs' Kyrie Irving on 'Earth is flat' comments: 'I know the science'
# Retrieving information for:  How Aaron Gordon's expected coronation jam lost its buzz
# Retrieving information for:  LeBron James: Can't compare me vs. Stephen Curry to classic rivalries
# Retrieving information for:  Illawarra force NBL semifinal decider with victory over Adelaide
# Retrieving information for:  Grades: 3-point contest
# Retrieving information for:  Adam Silver: State laws 'important factor' in deciding future All-Star hosts
# Retrieving information for:  Adam Silver still happy meeting with Charles Oakley, James Dolan occurred
# Retrieving information for:  Grades: Skills Challenge
# Retrieving information for:  NBA Africa Game to be held in August in Johannesburg
# Retrieving information for:  Rollie Massimino, Chris Webber among finalists for Basketball Hall of Fame
# Retrieving information for:  Carmelo Anthony welcomes All-Star break, despite canceled vacation
# Retrieving information for:  NBA's Last 2 Minute report says Marcus Smart's foul on Jimmy Butler was correct call
# Retrieving information for:  Mark Cuban takes apparent jab at Donald Trump with No. 46 jersey
# Retrieving information for:  Pacers make 2017 first-round pick available in push to aid Paul George
# Retrieving information for:  Jamal Murray, Buddy Hield lead World past U.S. in Rising Stars
# Retrieving information for:  #NBArank Rising Stars: Your list of the NBA's top players under 25
# Retrieving information for:  Athens artist paints giant Giannis image on court 'where it all began'
# Retrieving information for:  DeMarcus Cousins and others talk at NBA All-Star media day
# Retrieving information for:  Spurs' Pau Gasol elected to 3-year term on NBPA executive committee
# Retrieving information for:  'NBA legend' Charles Oakley joins BIG3, will serve as player/coach
# Retrieving information for:  NBA says Texas' proposed 'bathroom bill' could cost state events
# Retrieving information for:  Allen Iverson, Kenyon Martin among former NBA players to join 3-on-3 league
# Retrieving information for:  Russell Westbrook pivots on subject of Kevin Durant: 'Fashion week has been great'
# Retrieving information for:  NBPA preparing to handle players' licensing in new CBA
# Retrieving information for:  Paul George hesitant on new Pacers contract, wants to 'play on a winning team'
# Retrieving information for:  Charles Oakley on James Dolan: 'Some things can't be solved'
# Retrieving information for:  Jimmy Butler is rising over a bunch of bull
# Retrieving information for:  Steve Kerr keeping 'Warriors + 1' All-Star choice close to vest
# Retrieving information for:  Anthony Davis has come a long way as New Orleans' main attraction
# Retrieving information for:  Despite Pelicans' struggles, Anthony Davis 'here to stay'
# Retrieving information for:  Celtics up in arms after Bulls win on Jimmy Butler's free throws
# Retrieving information for:  Draymond Green: Remarks about James Dolan 'came off the wrong way'
# Retrieving information for:  Ten things I like and don't like, including The Beard's TD passes
# Retrieving information for:  Kevin Durant: Super excited to help basketball grow, see Taj Mahal
# Retrieving information for:  Timberwolves leadership says playoffs still a priority this season
# Retrieving information for:  Isaiah Thomas' 20-point streak reaches Celtics' record 41 games
# Retrieving information for:  #NBArank Rising Stars: 26-30
# Retrieving information for:  #NBArank Rising Stars: Top 50 under 25
# Retrieving information for:  #NBArank Rising Stars Nos. 1-5
# Retrieving information for:  #NBArank Rising Stars: 6-10
# Retrieving information for:  #NBArank Rising Stars: 11-15
# Retrieving information for:  #NBArank Rising Stars: Nos. 16-20
# Retrieving information for:  #NBArank Rising Stars: 21-25
# Retrieving information for:  #NBArank Rising Stars: Nos. 31-40
# Retrieving information for:  #NBArank Rising Stars: Nos. 41-50
# Retrieving information for:  DeMarcus Cousins 'very happy' with Kings, hopes to sign extension
# Retrieving information for:  Draymond Green: Knicks owner James Dolan using 'slave master mentality'
# Retrieving information for:  Ex-NBA player Shane Battier named head of Heat analytics department
# Retrieving information for:  76ers' Joel Embiid 'more surprised' than anyone by 2016-17 success
# Retrieving information for:  Kevin Garnett says Thon Maker has 'a chance to be special'
# Retrieving information for:  Pepsi, Cavs star Kyrie Irving collaborating on Uncle Drew film
# Retrieving information for:  Zaza Pachulia, Justin Bieber, Macedonian Twitter bots and the insanity of NBA All-Star voting
# Retrieving information for:  Carmelo Anthony to replace injured Kevin Love for All-Star Game
# Retrieving information for:  Cavs' Kevin Love played 3 games with injured knee
# Retrieving information for:  Manu Ginobili leaves Spurs' win over Magic with left ankle injury
# Retrieving information for:  Jeff Van Gundy says Knicks should retire Charles Oakley's number
# Retrieving information for:  Knicks retain No. 1 spot in Forbes' NBA team valuations
# Retrieving information for:  76ers expect Ben Simmons to play this season, 'just don't know when'
# Retrieving information for:  Amid trade rumors, Jahlil Okafor expected to play against Celtics
# Retrieving information for:  Under Armour CEO Kevin Plank answers criticism of Trump praise
# Retrieving information for:  Carmelo Anthony expects to be with Knicks after trade deadline
# Retrieving information for:  Joel Embiid out of All-Star Weekend events with injured knee
# Retrieving information for:  Bucks' forward Jabari Parker has ACL surgery, expected to miss 12 months
# Retrieving information for:  Would a big move at the trade deadline get the Pistons unstuck?
# Retrieving information for:  Cavs' Kevin Love has surgery on left knee, out 6 weeks
# Retrieving information for:  Knicks lift ban on Charles Oakley, but he wants apology
# Retrieving information for:  Bulls' Jimmy Butler back from injury, gets double-double in win
# Retrieving information for:  Marco Belinelli offers advice to Kemba Walker for Three-Point Contest
# Retrieving information for:  Newly acquired Mason Plumlee to make Nuggets debut Wednesday
# Retrieving information for:  Dwyane Wade (wrist) out against Raptors
# Retrieving information for:  Magic deal Serge Ibaka to Raptors for Terrence Ross, first-round pick
# Retrieving information for:  How about a "DoZen DeRoses" for your boo this Valentine's Day?
# Retrieving information for:  Development League to be renamed NBA Gatorade League
# Retrieving information for:  Magic Johnson on fixing Lakers: Want Kobe Bryant to 'be a part of it'
# Retrieving information for:  Sitting LeBron makes perfect sense
# Retrieving information for:  Durant, Westbrook set to switch from rivals to All-Star teammates
# Retrieving information for:  Magic Johnson says Lakers' brass must work in concert
# Retrieving information for:  Centers of attention: SNL's Leslie Jones fixes the Knicks and chats with Kristaps Porzingis
# Retrieving information for:  Adam Silver, Michael Jordan step in to help repair James Dolan-Charles Oakley relationship
# Retrieving information for:  Hawks coach ends speculation about Paul Millsap: 'He's not going anywhere'
# Retrieving information for:  LaMarcus Aldridge: Spurs' single All-Star to Warriors' 4 wrong
# Retrieving information for:  Stadium food: How to make the Staples Center Mac 'N' Cheese dog
# Retrieving information for:  Power Rankings: Warriors own the weekend; Heat rise into the top 10
# Retrieving information for:  Jusuf Nurkic arrives in Portland after trade and 'ready to work'
# Retrieving information for:  Wanda Durant trolls Thunder fans by claiming she loves cupcakes
# Retrieving information for:  Deron Williams tossed vs. Celtics
# Retrieving information for:  Gregg Popovich disappointed with President Trump's lack of outreach to some groups
# Retrieving information for:  Jazz, Qualtrics partner on jersey sponsorship for charity
# Retrieving information for:  Sixers' Bryan Colangelo: Minor tear not causing Joel Embiid's knee pain
# Retrieving information for:  J.R. Smith making rapid recovery from thumb injury
# Retrieving information for:  Warriors won't have Klay Thompson, Shaun Livingston vs. Nuggets
# Retrieving information for:  Matt Barnes: DeMarcus Cousins must 'be himself' despite rep
# Retrieving information for:  Cavs deal Chris 'Birdman' Andersen to Hornets to clear roster spot
# Retrieving information for:  Kevin Love to miss Tuesday's game vs. Timberwolves due to knee soreness
# Retrieving information for:  Nuggets get Mason Plumlee from Blazers for Jusuf Nurkic; Portland adds another 1st-round pick in deal
# Retrieving information for:  Doc Rivers' All-Star Game advice: Keep your enemies happy
# Retrieving information for:  Buddy Hield ejected for hitting DeMarcus Cousins in the groin
# Retrieving information for:  Latrell Sprewell and other former Knicks sit with owner James Dolan
# Retrieving information for:  Spike Lee calls James Dolan-Charles Oakley incident 'insanity'
# Retrieving information for:  Dwyane Wade out Sunday, X-rays negative on injured right wrist
# Retrieving information for:  Kevin Durant's mom hurt by 'vicious things' said in return to OKC
# Retrieving information for:  Charles Oakley responds to James Dolan's implications
# Retrieving information for:  Kevin Durant eats at restaurant after request to rent it out denied
# Retrieving information for:  Kevin Durant hears it from Thunder fans, then leads Warriors to win
# Retrieving information for:  LeBron James wants Cleveland to extend 10-day deal with Derrick Williams
# Retrieving information for:  76ers sit Jahlil Okafor as trade talks heat up
# Retrieving information for:  Kings, Hawks embrace new social media policy, become best friends
# Retrieving information for:  Joel Embiid dances shirtless for Philly at Meek Mill concert
# Retrieving information for:  Russell Westbrook on Durant's return: 'Got to move forward'
# Retrieving information for:  Hornets' Cody Zeller sits out Saturday's game vs. Clippers with sore quad
# Retrieving information for:  As KD returns, looking back on his OKC exit
# Retrieving information for:  NBA memo: Rules prohibit mocking of opponents on social media
# Retrieving information for:  Knicks owner James Dolan to honor agreement with Phil Jackson, won't meddle
# Retrieving information for:  Sources: Kevin Durant traveling with enhanced security on OKC visit
# Retrieving information for:  Carmelo Anthony: Getting through 'cloud' even worse than it looks from outside
# Retrieving information for:  Knicks ban Charles Oakley indefinitely, fire MSG security chief
# Retrieving information for:  Magic Johnson on Lakers adviser role: 'Working to call the shots'
# Retrieving information for:  Alex Len suspended one game for leaving bench area
# Retrieving information for:  Bulls' Dwyane Wade to return vs. Suns; Jimmy Butler also playing
# Retrieving information for:  Jimmy Butler producing at MJ-type level for Chicago
# Retrieving information for:  Durant's return to OKC a reunion made for the NBA
# Retrieving information for:  Ten (12) things I like and don't like, including the streaking Miami Heat
# Retrieving information for:  Knicks owner James Dolan says Charles Oakley banned from MSG
# Retrieving information for:  Is the Lakers' young core making the right strides?
# Retrieving information for:  Charles Oakley says James Dolan isn't open to fixing their issues
# Retrieving information for:  Pelton mailbag: How will Ben Simmons compare to Ricky Rubio?
# Retrieving information for:  What Kevin Durant left behind in Oklahoma City
# Retrieving information for:  Suns' Devin Booker focused on following footsteps of NBA greats
# Retrieving information for:  Knicks president Phil Jackson tweets that he's 'against discord'
# Retrieving information for:  C.J. McCollum, Chandler Parsons trade barbs on Twitter
# Retrieving information for:  Cavaliers' Big 3 'keep it rolling' rather than rest against Thunder
# Retrieving information for:  Cavs sign Derrick Williams to 10-day deal after release from Heat
# Retrieving information for:  Athletes react to Jabari Parker's season-ending injury
# Retrieving information for:  Jabari Parker tears left ACL for 2nd time, will miss 12 months
# Retrieving information for:  Jimmy Butler (heel) vows to be 100 percent before rejoining Bulls
# Retrieving information for:  James, Wade, Paul among those critical of Oakley's arrest
# Retrieving information for:  Kevin Durant talks hurting Thunder fans, looking forward to matchup
# Retrieving information for:  Stephen Curry disagrees with Under Armour CEO about Donald Trump
# Retrieving information for:  Magic's Aaron Gordon day-to-day with bruised foot
# Retrieving information for:  Charles Oakley arrested, charged with assault after MSG altercation
# Retrieving information for:  NBA, Take-Two Interactive Software partnering on NBA 2K esports league
# Retrieving information for:  Spike Lee 'still believes' in Melo, says time for Phil Jackson to go
# Retrieving information for:  Broken hand to sideline Blazers' Evan Turner up to 6 weeks
# Retrieving information for:  Jabari Parker sprains knee as Bucks get Khris Middleton back
# Retrieving information for:  Kenneth Faried leaves Nuggets game with sprained right ankle
# Retrieving information for:  Dragan Bender recovering from ankle surgery, Suns say
# Retrieving information for:  Sprained ankle sidelines Pelicans' Tyreke Evans versus Utah Jazz
# Retrieving information for:  Police release video of Kobe Bryant memorabilia theft
# Retrieving information for:  Bucks to start D-League team in Oshkosh
# Retrieving information for:  Magic awaiting test results on Aaron Gordon's sore foot
# Retrieving information for:  James Harden on current Rockets: 'I love what we have'
# Retrieving information for:  Timberwolves sign Lance Stephenson to 10-day contract
# Retrieving information for:  Ramon Sessions out 4-6 weeks after knee surgery
# Retrieving information for:  LeBron James not concerned about Cavaliers not limiting his minutes
# Retrieving information for:  Joe Lacob: Michael Jordan not impressed with Warriors' record 73-win season
# Retrieving information for:  Phil Jackson on column about Carmelo Anthony: 'You don't change the spot on a leopard'
# Retrieving information for:  Sixers' Joel Embiid to sit out against Spurs, Magic
# Retrieving information for:  As Johnson joins the Lakers, what changes for the franchise?
# Retrieving information for:  John Wall: 'I really thought I was gonna die'
# Retrieving information for:  Tom Thibodeau says Lance Stephenson is strong candidate for 10-day contract
# Retrieving information for:  Sources: Draymond Green purposely tried to rile up, motivate Kevin Durant
# Retrieving information for:  Blazers' Evan Turner breaks right hand during game against Mavericks
# Retrieving information for:  Kevin Durant talks OKC return and 'fake drama' involving Russell Westbrook
# Retrieving information for:  Timberwolves F Adreian Payne out indefinitely with low platelet count
# Retrieving information for:  Khris Middleton hoping to spark Bucks after return from injury
# Retrieving information for:  DeMarcus Cousins receives automatic suspension for picking up 16th tech, fined $25K
# Retrieving information for:  Power Rankings: Bracing for Durant's Oklahoma City reunion
# Retrieving information for:  Which NBA team should you sign with in free agency?
# Retrieving information for:  Which NBA team should you sign with in free agency?
# Retrieving information for:  Brandon Jennings: 'That's the worst we've looked this season'
# Retrieving information for:  Kings won't deal DeMarcus Cousins before Feb. 23 deadline, Divac says
# Retrieving information for:  Warriors raising ticket prices again
# Retrieving information for:  Sources: Pelicans talking trade with Sixers for Jahlil Okafor
# Retrieving information for:  Cavs insist Kevin Love won't be traded with deadline on horizon
# Retrieving information for:  DeMarcus Cousins earns 16th tech, faces automatic 1-game suspension
# Retrieving information for:  Bulls' Jimmy Butler still out with heel bruise versus Kings
# Retrieving information for:  Iman Shumpert seen in walking boot after suffering ankle sprain
# Retrieving information for:  Former NBA star Dennis Rodman gets probation in freeway crash
# Retrieving information for:  Derrick Rose returns after missing past four games with ankle injury
# Retrieving information for:  Tyronn Lue, LeBron James see parallel in Pats, Cavs titles
# Retrieving information for:  Steve Kerr fined $25K for verbal abuse of official Bill Spooner
# Retrieving information for:  Heat sign rookie forward Okaro White through 2017-18 season
# Retrieving information for:  Kobe Bryant memorabilia stolen from ex-NBA star's alma mater
# Retrieving information for:  'They'll find time to respect me'
# Retrieving information for:  Melbourne stay in NBL playoffs hunt with win over Illawarra
# Retrieving information for:  Timberwolves' Zach LaVine has torn ACL, to miss rest of season
# Retrieving information for:  Paul Pierce hits a 3-pointer in final seconds of Garden finale
# Retrieving information for:  After singer flubs 'O Canada' lyrics, Raptors troll Nets on Twitter
# Retrieving information for:  Paul Pierce gets starting nod in Boston farewell
# Retrieving information for:  Gregg Popovich notches NBA-record 1,128th victory with Spurs
# Retrieving information for:  Knicks' Carmelo Anthony says he's trying to remain optimistic amid trade rumors
# Retrieving information for:  Warriors coach Steve Kerr goes off on official, ejected for arguing
# Retrieving information for:  Cavs' Kyrie Irving misses win vs. Knicks due to right quad soreness
# Retrieving information for:  Players around the league react to Zach LaVine's recent injury news
# Retrieving information for:  Warriors sign Briante Weber, waive Anderson Varejao
# Retrieving information for:  Instant impact: Mavs to sign Yogi Ferrell to 2-year deal
# Retrieving information for:  LeBron James: 'Just want the best' for Carmelo Anthony, no matter where he plays
# Retrieving information for:  Bulls 'play it safe' with Jimmy Butler, sit him with bruised heel
# Retrieving information for:  Rockets celebrate Yao Ming as Hall of Famer's No. 11 jersey retired
# Retrieving information for:  Brad Stevens to coach East All-Stars, as Celtics seal No. 2 slot
# Retrieving information for:  Bucks' Khris Middleton cleared to return to game action Wednesday
# Retrieving information for:  Taurean Prince, James Johnson fined for roles in Wednesday scuffle in Miami
# Retrieving information for:  Despite rumors of trade talks with Knicks, Kevin Love doesn't expect Cavaliers to trade him
# Retrieving information for:  Michael Malone: Trade rumors about Wilson Chandler, Emmanuel Mudiay are 'a lot of noise'
# Retrieving information for:  Pelton mailbag: Is it time to rethink Austin Rivers' value?
# Retrieving information for:  Nuggets' Nikola Jokic (hip) to return Friday after 3-game absence
# Retrieving information for:  Do the Rockets pose a realistic threat to the Warriors?
# Retrieving information for:  Gregg Popovich on mark: 'Just a longevity thing more than anything'
# Retrieving information for:  Magic Johnson to help Jeanie Buss with evaluation of Lakers franchise
# Retrieving information for:  Dwight Howard: Win 'felt good,' but no added motivation vs. Houston
# Retrieving information for:  Aaron Gordon back in All-Star dunk contest; Klay Thompson to defend 3-point title
# Retrieving information for:  Spurs' Pau Gasol (hand) expected back by end of All-Star break
# Retrieving information for:  Sources: Jordan Farmar impresses Cavs, would accept 10-day contract
# Retrieving information for:  76ers' Nerlens Noel out at San Antonio with respiratory infection
# Retrieving information for:  Warriors' Klay Thompson to defend 3-point contest title
# Retrieving information for:  Bucks trade Miles Plumlee for Hornets' Spencer Hawes, Roy Hibbert
# Retrieving information for:  All-Time #NBArank: Hakeem No. 10
# Retrieving information for:  All-Time #NBArank: Duncan No. 8
# Retrieving information for:  All-Time #NBArank: Shaq No. 9
# Retrieving information for:  All-Time #NBArank: Russell No. 7
# Retrieving information for:  All-Time #NBArank: Bird No. 6
# Retrieving information for:  Durant, Warriors among reasons for LeBron's frustrations
# Retrieving information for:  Cavs not swayed by Knicks' continued pursuit of Kevin Love in Melo talks
# Retrieving information for:  #NBArank Rising Stars: Vote now!
# Retrieving information for:  Has Eric Bledsoe played his way into or out of the Suns' future?
# Retrieving information for:  Derrick Rose remains out for Knicks due to sprained left ankle
# Retrieving information for:  LeBron OK with players Cavaliers trying out, even Lance Stephenson
# Retrieving information for:  Mark Cuban questions 'hypocrisy' of Donald Trump immigration order
# Retrieving information for:  Kings' Garrett Temple to miss 2-3 weeks with partially torn hamstring
# Retrieving information for:  Will Andrew Wiggins ever make Cavaliers regret trading him?
# Retrieving information for:  Kings' Matt Barnes turns himself in, released over N.Y. club incident
# Retrieving information for:  LeBron James to receive NAACP Jackie Robinson Sports Award
# Retrieving information for:  Charles Barkley laughs off LeBron James' barbs, stands by critique of Cavaliers star
# Retrieving information for:  Cavaliers to work out Kirk Hinrich, Mario Chalmers, Lance Stephenson, Jordan Farmar
# Retrieving information for:  Photos: New York, Taiwan and the Knicks during peak Linsanity
# Retrieving information for:  Luol Deng expands on comments about travel and immigration ban
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-f707e99abfb0> in <module>()
#       9     results = soup.find(id='article-feed')
#      10     #print(results.prettify())
# ---> 11     if results.find_all('div', class_='container') == "NoneType":
#      12             break
#      13     job_elems = results.find_all('div', class_='container')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
title = name.text.strip().replace(" ","")
df.to_csv(title+".csv")


    
end = time.time()
print((end - start) / 60,"Minutes")
os.chdir("..")
# Out:
# 8.9928937514623 Minutes

# %%
print(title+".csv")
# Out:
# Jan30,2017.csv

# %%
name
